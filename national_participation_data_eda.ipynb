# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/national-participation-data.csv')

# displaying data
df.head()
# Out:
#    data_year  population  total_agency_count  published_agency_count  \
# 0       2021   331900098               18810                   11830
# 1       2020   332643466               18625                   15878
# 2       2019   331433049               18674                   15334
# 3       2018   330362587               18558                   15281
# 4       2017   329104541               18473                   16427
#
#    active_agency_count  covered_agency_count  population_covered  \
# 0                21477                     9               12334
# 1                21286                    13               20758
# 2                21325                    17               18828
# 3                21225                    39               18737
# 4                21122                    29               51097
#
#    agency_count_nibrs_submitting  agency_count_leoka_submitting  \
# 0                          11863                          12112
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   data_year                      43 non-null     int64
#  1   population                     43 non-null     int64
#  2   total_agency_count             43 non-null     int64
#  3   published_agency_count         43 non-null     int64
#  4   active_agency_count            43 non-null     int64
#  5   covered_agency_count           43 non-null     int64
#  6   population_covered             43 non-null     int64
#  7   agency_count_nibrs_submitting  43 non-null     int64
#  8   agency_count_leoka_submitting  43 non-null     int64
#  9   agency_count_pe_submitting     43 non-null     int64
#  10  agency_count_srs_submitting    43 non-null     int64
#  11  agency_count_supp_submitting   43 non-null     int64
# ...

# %%
total = df.isnull().sum().sort_values(ascending=False)
total
# Out:
# data_year                        0
# population                       0
# total_agency_count               0
# published_agency_count           0
# active_agency_count              0
# covered_agency_count             0
# population_covered               0
# agency_count_nibrs_submitting    0
# agency_count_leoka_submitting    0
# agency_count_pe_submitting       0
# agency_count_srs_submitting      0
# agency_count_supp_submitting     0
# nibrs_population_covered         0
# dtype: int64

# %%
import seaborn as sns
sns.histplot(df['population'])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True, cmap='Blues')

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='total_agency_count',y='covered_agency_count',data=df)
plt.xlabel('total_agency_count')
plt.ylabel('covered_agency_count')
# Out:
# Text(0, 0.5, 'covered_agency_count')

# %%
df.boxplot()

# %%
df.boxplot(column=['total_agency_count']
